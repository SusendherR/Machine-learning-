# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, depandent, test_size =1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','poly','sigmoid','linear'],'C':[0.01,10,100,1000,2000,3000],'gamma':['auto','scale']}
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [0.01, 10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for the best paramentr{}:".format(grid.best_params_))
# Out:
# The R_score value for the best paramentr{'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}:

# %%
tabel=pd.DataFrame.from_dict(re)

# %%
tabel
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.097300      0.019591         0.058595        0.010981    0.01
# 1        0.081516      0.015647         0.013815        0.009590    0.01
# 2        0.109082      0.005321         0.022440        0.009182    0.01
# 3        0.090256      0.004673         0.017348        0.002966    0.01
# 4        0.102326      0.005227         0.064893        0.001535    0.01
# 5        0.091862      0.007221         0.019614        0.005862    0.01
# 6        0.118860      0.007830         0.021153        0.005780    0.01
# 7        0.100787      0.007034         0.015296        0.001583    0.01
# 8        0.116834      0.014223         0.064504        0.010736      10
# 9        0.101989      0.006369         0.014574        0.004409      10
# 10       0.113933      0.006948         0.024044        0.006905      10
# 11       0.094104      0.006741         0.015020        0.003778      10
# ...

# %%
age_input=float (input("Age:"))
bmi_input=float(input("BMI"))
Children_input=float(input("children:"))
sex_male_input=int(input("sex male 0 or 1:"))
smoker_yes_input=int(input("smoker yes 0 or 1:"))
# Out:
# Age: 45
# BMI 65
# children: 2
# sex male 0 or 1: 0
# smoker yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,Children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[9965778.66182016]

# %%
import pickle
filename="finalized_GridSearchCV.sav"
pickle.dump(GridSearchCV,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("finalized_GridSearchCV.sav",'rb'))
result=loaded_model.predict([[19,27.900,0,0,1]])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 2
#       1 loaded_model=pickle.load(open("finalized_GridSearchCV.sav",'rb'))
# ----> 2 result=loaded_model.predict([[19,27.900,0,0,1]])
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_available_if.py:41, in _AvailableIfDescriptor.__get__.<locals>.out(*args, **kwargs)
#      39 @wraps(self.fn)
#      40 def out(*args, **kwargs):
# ---> 41     if not self.check(args[0]):
#      42         raise attr_err
#      43     return self.fn(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:359, in _estimator_has.<locals>.check(self)
#     358 def check(self):
# --> 359     _check_refit(self, attr)
#     360     if hasattr(self, "best_estimator_"):
#     361         # raise an AttributeError if `attr` does not exist
#     362         getattr(self.best_estimator_, attr)
#
# ...

# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
depandent=dataset['charges']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, depandent, test_size =1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {
    'kernel':['rbf','poly','sigmoid','linear'],
    'C':[0.01,10,100,1000,2000,3000],
    'gamma':['auto','scale']}
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [0.01, 10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
from sklearn.model_selection import GridSearchCV
print("value for the best paramentr:",grid.best_params_)
best_index = grid.best_index_
best_r2_score = grid.cv_results_['mean_test_score'][best_index]
print("r2:",best_r2_score)
# Out:
# value for the best paramentr: {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}
# r2: 0.7998077775380026

# %%
table=pd.DataFrame.from_dict(grid.cv_results_)

# %%
table[['rank_test_score', 'mean_test_score', 'params']].sort_values('rank_test_score')
# Out:
#     rank_test_score  mean_test_score  \
# 45                1         0.799808
# 41                2         0.799749
# 37                3         0.798046
# 33                4         0.797957
# 40                5         0.790300
# 44                6         0.790281
# 29                7         0.787808
# 25                8         0.787499
# 32                9         0.775086
# 36               10         0.775041
# 24               11         0.691544
# 28               12         0.691485
# 31               13         0.600119
# 27               13         0.600119
# 35               15         0.595666
# 39               15         0.595666
# 47               17         0.595130
# 43               17         0.595130
# 19               19         0.585008
# 23               19         0.585008
# 21               21         0.506299
# 17               22         0.506281
# 18               23         0.474000
# 22               24         0.473708
# 15               25         0.355112
# 11               25         0.355112
# 30               27         0.315846
# 26               28         0.282901
# 16               29         0.229703
# 20               30         0.229672
# 13               31         0.000877
# 9                32         0.000826
# 14               33        -0.004968
# 10               34        -0.004978
# 8                35        -0.057387
# 12               36        -0.057395
# 7                37        -0.099872
# 3                37        -0.099872
# 5                39        -0.100368
# 1                40        -0.100368
# 6                41        -0.100377
# 2                42        -0.100377
# 0                43        -0.100433
# 4                44        -0.100433
# 38               45        -0.342681
# 34               46        -0.399268
# 42               47        -1.505790
# 46               48        -1.561068
#
#                                                params
# 45    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}
# 41     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}
# 37    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}
# 33     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}
# 40      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}
# 44     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}
# 29    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}
# 25     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}
# 32      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}
# 36     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}
# 24      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}
# 28     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}
# 31  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}
# 27   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}
# 35   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}
# 39  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}
# 47  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}
# 43   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}
# 19    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}
# 23   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}
# 21     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}
# 17      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}
# 18   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 22  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 15    {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
# 11     {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}
# 30  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...
# 26  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 16       {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}
# 20      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
# 13      {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}
# 9        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}
# 14   {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 10    {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 8         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# 12       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 7   {'C': 0.01, 'gamma': 'scale', 'kernel': 'linear'}
# 3    {'C': 0.01, 'gamma': 'auto', 'kernel': 'linear'}
# 5     {'C': 0.01, 'gamma': 'scale', 'kernel': 'poly'}
# 1      {'C': 0.01, 'gamma': 'auto', 'kernel': 'poly'}
# 6   {'C': 0.01, 'gamma': 'scale', 'kernel': 'sigmo...
# 2   {'C': 0.01, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 0       {'C': 0.01, 'gamma': 'auto', 'kernel': 'rbf'}
# 4      {'C': 0.01, 'gamma': 'scale', 'kernel': 'rbf'}
# 38  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...
# 34  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 42  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 46  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...

# %%
age_input=float (input("Age:"))
bmi_input=float(input("BMI"))
Children_input=float(input("children:"))
sex_male_input=int(input("sex male 0 or 1:"))
smoker_yes_input=int(input("smoker yes 0 or 1:"))
# Out:
# Age: 76
# BMI 56
# children: 2
# sex male 0 or 1: 1
# smoker yes 0 or 1: 1

# %%
best_model = grid.best_estimator_

# %%
import pickle
filename="finalized_GridSearchCV.sav"
pickle.dump(best_model,open(filename, 'wb'))

# %%
loaded_model=pickle.load(open("finalized_GridSearchCV.sav", 'rb'))
result=loaded_model.predict([[19,27.900,0,0,1]])
print(result)
# Out:
# [497391.81192653]
